# %% [markdown]
# <a href="https://colab.research.google.com/github/MohanVishe/Notes/blob/main/003B_Python_Image_Scrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT

# %%
import requests
import os

# %% [markdown]
# ### 1.To scrap data or something from : HTML,XML pages
#  * (pip install bs4)

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ### 2.request something to any particular server
#  * (pip install urllib)

# %%
from urllib.request import urlopen

# %% [markdown]
# ### 3.Logging Setup:
#
#  * Adding a basic logging setup using the logging module. This will help you track the progress and any errors that might occur during the scraping process.

# %%
import logging

# %% [markdown]
# ###   4.Make folder to store the Data (image)

# %%
save_dir="image_store/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %% [markdown]
# ### 5.Taking Web URL As shown

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
query="chandrayaan"

# %% [markdown]
# ### 6. The requests.get()
# * Function is part of the requests library in Python, which is used for making HTTP requests to web servers. It's a versatile function that allows you to send GET requests to a specified URL and retrieve the content of the response.

# %%
response=requests.get(f"""https://www.google.com/search?q={query}&tbm=isch&ved=
                      2ahUKEwjXz-ePvNSAAxXRz6ACHUz_DHkQ2-cCegQIABAA&oq=chandrayaan&gs
                      _lcp=CgNpbWcQARgAMgQIIxAnMggIABCxAxCDATIECAAQAzINCAAQigUQsQMQgw
                      EQQzINCAAQigUQsQMQgwEQQzIECAAQAzIECAAQAzIECAAQAzILCAAQgAQQsQMQg
                      wEyCwgAEIAEELEDEIMBUABYAGCVC2gAcAB4AIABaYgBaZIBAzAuMZgBAKoBC2d3
                      cy13aXotaW1nwAEB&sclient=img&ei=GRfWZJffItGfg8UPzP6zyAc&bih=568
                      &biw=1033&rlz=1C1ONGR_enIN1066IN1066""")

# %% [markdown]
# ### 7. `response.status_code`
# * refers to the HTTP status code that is returned by the server in response to the HTTP request you made using the `requests` library. The HTTP status code is a three-digit number that indicates the outcome of the request.
#
# Here are some common HTTP status codes and their meanings:
#
#   - **200 OK**: The request was successful, and the server has returned the requested data.
#   - **404 Not Found**: The requested resource could not be found on the server.
#   - **403 Forbidden**: The server understood the request, but the server refuses to authorize it.
#   - **500 Internal Server Error**: The server encountered an unexpected condition that prevented it from fulfilling the request.

# %%
response
# Out:
# <Response [200]>

# %%
BeautifulSoup(response.content,"html.parser")
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %% [markdown]
# ### 8. To get The html page

# %%
if response.status_code==200:
  # Parse the HTML content using BeautifulSoup
  soup=BeautifulSoup(response.content,"html.parser")
  # we get the complete html page

# %% [markdown]
# ### 9 To get specific type of Data (images)

# %%
image_tags=soup.find_all('img')

# %%
image_tags
# click the link to see the images that we extracted
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSqg4iBZS2ZehYz2iAHYW02j7UmcDibigeW8Wh1yWH_mrYpBnvIuAuWNRn1Ic&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSHpFmsc6-z6x3u6TrVqs4lOmRD7507Xp9eZdS9ECOgcgWIHVDq0K6jA-89oE8&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQyl4j5hrbnsyzr4CQNasrwXTcpkStlm-QfPaY-9nx3AZ8Tr-nTB6ipM2EJsAQ&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQGnVYmkXdl0nesr_Nr_zYd6tLgPgZ1YbaW6Dlrrxzd2sGNz3GBxL-loUwlpwM&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgqil3InboYu2NWiqhhW4RVwVbWmUPyFjFjgCgkaJYLGPGJbSZKydH6KX3dwk&amp;s"/>,
# ...

# %% [markdown]
# * Click the link to see the images that we extracted

# %% [markdown]
# ###  10. Removing 1st tag as it dont have any link to images

# %%
image_tags[0]
# this dont have any image link
# Out:
# <img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>

# %%
del image_tags[0]

# %%
image_tags
# Out:
# [<img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSqg4iBZS2ZehYz2iAHYW02j7UmcDibigeW8Wh1yWH_mrYpBnvIuAuWNRn1Ic&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSHpFmsc6-z6x3u6TrVqs4lOmRD7507Xp9eZdS9ECOgcgWIHVDq0K6jA-89oE8&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQyl4j5hrbnsyzr4CQNasrwXTcpkStlm-QfPaY-9nx3AZ8Tr-nTB6ipM2EJsAQ&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQGnVYmkXdl0nesr_Nr_zYd6tLgPgZ1YbaW6Dlrrxzd2sGNz3GBxL-loUwlpwM&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgqil3InboYu2NWiqhhW4RVwVbWmUPyFjFjgCgkaJYLGPGJbSZKydH6KX3dwk&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTMMa-pSk9rFdT7VLdQQaZbTH2P4m5Pb4z2om7tGK-JtpCWfAo4OWBeK-DnUcg&amp;s"/>,
# ...

# %%
# total number of images
len(image_tags)
# Out:
# 20

# %% [markdown]
# ### 11. Extracting Images link only

# %%
for i in image_tags:
  print(i["src"]) #src is source of data
# Out:
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSqg4iBZS2ZehYz2iAHYW02j7UmcDibigeW8Wh1yWH_mrYpBnvIuAuWNRn1Ic&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSHpFmsc6-z6x3u6TrVqs4lOmRD7507Xp9eZdS9ECOgcgWIHVDq0K6jA-89oE8&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQyl4j5hrbnsyzr4CQNasrwXTcpkStlm-QfPaY-9nx3AZ8Tr-nTB6ipM2EJsAQ&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQGnVYmkXdl0nesr_Nr_zYd6tLgPgZ1YbaW6Dlrrxzd2sGNz3GBxL-loUwlpwM&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgqil3InboYu2NWiqhhW4RVwVbWmUPyFjFjgCgkaJYLGPGJbSZKydH6KX3dwk&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTMMa-pSk9rFdT7VLdQQaZbTH2P4m5Pb4z2om7tGK-JtpCWfAo4OWBeK-DnUcg&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRBSupWcY688vJalszm2S24DZLRYvmTuPvh4GrK6zqtFXgHrExkbFkWqfoLaA&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFvQc4qD1Z-EVPrmXnpZZh-DAFRjTNBJxdu5-0sUE3Yl9jf6ztYszbcvI3UHo&s
# ...

# %% [markdown]
# ### 13. Download Images

# %%
# Took one image link try to download the image

requests.get('''https://encrypted-tbn0.gstatic.com/
images?q=tbn:ANd9GcQ0ocwEEqLi1O9EZtRKluMO8o
LTUg-Y4sv-MtYoVg1A4WZm3vBpMNlmQOKyvg&s''')
# Out:
# <Response [200]>

# %%
# <response [200] means done
requests.get('''https://encrypted-tbn0.gstatic.com/
images?q=tbn:ANd9GcQ0ocwEEqLi1O9EZtRKluMO8o
LTUg-Y4sv-MtYoVg1A4WZm3vBpMNlmQOKyvg&s''').content
# we will get the binary form  of image data
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x08\x07\x06\t\x08\x07\x08\n\n\t\x0b\r\x16\x0f\r\x0c\x0c\r\x1b\x14\x15\x10\x16 \x1d"" \x1d\x1f\x1f$(4,$&1\'\x1f\x1f-=-157:::#+?D?8C49:7\x01\n\n\n\r\x0c\r\x1a\x0f\x0f\x1a7%\x1f%77777777777777777777777777777777777777777777777777\xff\xc0\x00\x11\x08\x00[\x00\xa2\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1b\x00\x00\x01\x05\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\xff\xc4\x00:\x10\x00\x01\x03\x02\x04\x04\x04\x04\x04\x03\t\x01\x00\x00\x00\x00\x01\x00\x02\x03\x04\x11\x05\x12!1\x13Aaq\x06"Q\x81\x142R\x91\x15Bb\xa1#\x82\xb1$34CDS\x92\xd1\xe1\x07\xff\xc4\x00\x19\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x04\x03\x05\xff\xc4\x00\x1c\x11\x01\x01\x01\x01\x00\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x11\x02\x03\x041Q!\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xf1g|\xee\xee\x91+\xbewwH\xa8\x1
# ...

# %%
for i in image_tags:
  image_data=requests.get(f"{i['src']}").content
    # save images in the folder ("wb"=write binary)
  with open(os.path.join(save_dir,f"{query}_{image_tags.index(i)}.jpg"),"wb")  as f :
    f.write(image_data)

# %% [markdown]
# # Create App
#
#
# * application.py

# %%
from flask import Flask, render_template, request,jsonify
import requests
from bs4 import BeautifulSoup
import logging
logging.basicConfig(filename="scrapper.log" , level=logging.INFO)
import os

application = Flask(__name__)
app=application

@app.route("/", methods = ['GET'])
def homepage():
  return render_template("index.html")

@app.route("/review" , methods = ['POST' , 'GET'])
def index():
  if request.method == 'POST':
    try:

      query = request.form['content'].replace(" ","")

      save_directory = "images/"

      # create the directory if it doesn't exist
      if not os.path.exists(save_directory):
        os.makedirs(save_directory)



      # fake user agent to avoid getting blocked by Google
      headers = {"User-Agent": """Mozilla/5.0 (Windows NT 10.0; Win64;
                 x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"""}

      # fetch the search results page
      response = requests.get(f"""https://www.google.com/search?q={query}&
        sxsrf=AJOqlzUuff1RXi2mm8I_OqOwT9VjfIDL7w:1676996143273&source=lnms&tbm
        =isch&sa=X&ved=2ahUKEwiq-qK7gaf9AhXUgVYBHYReAfYQ_AUoA3oECAEQBQ&biw=1920&bih
        =937&dpr=1#imgrc=1th7VhSesfMJ4M""")


      # parse the HTML using BeautifulSoup
      soup = BeautifulSoup(response.content, "html.parser")

      # find all img tags
      image_tags = soup.find_all("img")

      # download each image and save it to the specified directory
      del image_tags[0]
      img_data=[]
      for index,image_tag in enumerate(image_tags):
        # get the image source URL
        image_url = image_tag['src']
                        # send a request to the image URL and save the image
        image_data = requests.get(image_url).content
        mydict={"Index":index,"Image":image_data}
        img_data.append(mydict)
        with open(os.path.join(save_directory, f"{query}_{image_tags.index(image_tag)}.jpg"), "wb") as f:
          f.write(image_data)
      return "image loaded"
    except Exception as e:
      logging.info(e)
      return 'something is wrong'

  else:
    return render_template('index.html')

if __name__ == "__main__":
        app.run(host="0.0.0.0",port=8000)

# %% [markdown]
#  * index.html
#
# ```html
#
# {% extends 'base.html' %}
#
# {% block head %}
#
# <title>Search Page</title>
# <link rel="stylesheet" href="{{ url_for('static', filename='css/style.css') }}">
# {% endblock %}
#
# {% block body %}
# <div class="content">
#     <h1 style="text-align: center">Search</h1>
#
#     <div class="form">
#         <form action="/review" method="POST">
#             <input type="text" name="content" id="content">
#             <input type="submit" value="Search">
#         </form>
#     </div>
# </div>
# {% endblock %}
# ```

# %% [markdown]
# * base.html
#
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <link rel="stylesheet" href="{{ url_for('static', filename='css/main.css') }}">
#     {% block head %}{% endblock %}
# </head>
# <body>
#     {% block body %}{% endblock %}
# </body>
# </html>
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)
